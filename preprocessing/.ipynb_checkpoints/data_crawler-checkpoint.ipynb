# %%
from __future__ import print_function
import tweepy
import json
from pymongo import MongoClient

# %%
MONGO_HOST= 'mongodb://127.0.0.1:27017/twitterdb'  # assuming you have mongoDB installed locally
                                             # and a database called 'twitterdb'

WORDS = ['#airpod','#ipad','#macbook','#iphone','#iwatch']

CONSUMER_KEY = "MhaxeyqFvFtSYareo0PHDoMa8"
CONSUMER_SECRET = "5QjuEKhbO5OvgV1Flsbs6XHKcsYgmKx4paSznl2W0Nwcydo6Q3"
ACCESS_TOKEN = "851594289205432321-ybASrG4uQ0ozHMLo7AprXwu3SgKNtye"
ACCESS_TOKEN_SECRET = "gll5tNhyz59KbZ1C1oOcQadPdh8HBS6REiyKwV7F0vQbC"


class StreamListener(tweepy.StreamListener):    
    #This is a class provided by tweepy to access the Twitter Streaming API. 

    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")
 
    def on_error(self, status_code):
        # On error - if an error occurs, display the error / status code
        print('An Error has occured: ' + repr(status_code))
        return False
 
    def on_data(self, data):
        #This is the meat of the script...it connects to your mongoDB and stores the tweet
        try:
            client = MongoClient(MONGO_HOST)
            
            # Use twitterdb database. If it doesn't exist, it will be created.
            db = client.twitterdb
    
            # Decode the JSON from Twitter
            datajson = json.loads(data)
            
            #grab the 'created_at' data from the Tweet to use for display
            created_at = datajson['created_at']

            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(created_at))
            print('location:', datajson['user']['location'])
            print(datajson)
            print()
            print()
            print()
            
            #insert the data into the mongoDB into a collection called twitter_search
            #if twitter_search doesn't exist, it will be created.
            db.twitter_search.insert_one(datajson)
        except Exception as e:
           print(e)

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
#Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
streamer = tweepy.Stream(auth=auth, listener=listener)
print("Tracking: " + str(WORDS))
streamer.filter(languages=["en"], track=WORDS)
# Out:
# Tracking: ['#airpod', '#ipad', '#macbook', '#iphone', '#iwatch']
# You are now connected to the streaming API.
# Tweet collected at Fri Nov 30 07:51:04 +0000 2018
# location: NewYork ,Jamaica, South Africa
# {'created_at': 'Fri Nov 30 07:51:04 +0000 2018', 'id': 1068412079483355136, 'id_str': '1068412079483355136', 'text': 'RT @doctorappleita: #sand\n.\n.\nIf you want this #wallpaper, join my #telegram https://t.co/JGiV4xjNTd\n.\n#wallpapers #wallpaperoftheday #appl…', 'source': '<a href="http://blackberry.com/twitter" rel="nofollow">Twitter for BlackBerry®</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 743329664672772096, 'id_str': '743329664672772096', 'name': 'SkyPree Marketing', 'screen_name': 'MiaContent_1', 'location': 'NewYork ,Jamaica, South Africa', 'url': 'http://go.sky1876.com', 'description': 'Digital modern Marketing audience product alignment we will increase conversion of sales and visitors, awareness for your brand  https://t.co/tNBpiQYsL7', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 581, 'friends_count': 0, 'listed_count': 35, 'favourites_count': 132, 'statuses_count': 14994, 'created_at': 'Thu Jun 16 06:29:37 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/887615047899525120/i5-g-34p_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/887615047899525120/i5-g-34p_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/743329664672772096/1502086838', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': '
jpg', 'media_url_https': 'https://pbs.twimg.com/media/DtPEDiHWsAE62Q1.jpg', 'url': 'https://t.co/AfJtkVQjpY', 'display_url': 'pic.twitter.com/AfJtkVQjpY', 'expanded_url': 'https://twitter.com/LtdEu/status/1068413699340345345/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 750, 'h': 422, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 422, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}, {'id': 1068413224830287872, 'id_str': '1068413224830287872', 'indices': [269, 292], 'media_url': 'http://pbs.twimg.com/media/DtPEKtNWwAAoiVm.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DtPEKtNWwAAoiVm.jpg', 'url': 'https://t.co/AfJtkVQjpY', 'display_url': 'pic.twitter.com/AfJtkVQjpY', 'expanded_url': 'https://twitter.com/LtdEu/status/1068413699340345345/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 169, 'h': 225, 'resize': 'fit'}, 'medium': {'w': 169, 'h': 225, 'resize': 'fit'}, ' ...
#
#
#
# Tweet collected at Fri Nov 30 07:57:45 +0000 2018
# location: Horsens, Danmark
# {'created_at': 'Fri Nov 30 07:57:45 +0000 2018', 'id': 1068413760958812160, 'id_str': '1068413760958812160', 'text': 'I finished the "Find a compromise" task in Big Business Deluxe for iOS! https://t.co/0B6hUmKWWs #iPhone #GameInsight #iPhoneGames', 'source': '<a href="http://www.game-insight.com/" rel="nofollow">Big Business Deluxe for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3021248193, 'id_str': '3021248193', 'name': 'STEN I. Panduro', 'screen_name': 'i_carsten', 'location': 'Horsens, Danmark', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 0, 'friends_count': 3, 'listed_count': 0, 'favourites_count': 0, 'statuses_count': 358, 'created_at': 'Fri Feb 06 10:58:06 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'da', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'iPhone', 'indices': [96, 103]}, {'text': 'GameInsight', 'indices': [104, 116]}, {'text': 'iPhoneGames', 'indices': [117, 129]}], 'urls': [{'url': 'https://t.co/0B6hUmKWWs', 'expanded_url': 'http://tinyurl.com/kgkeww6', 'display_url': 'tinyurl.com/kgkeww6', 'indices': [72, 95]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1543564665437'}
#
#
#
# Tweet collected at Fri Nov 30 07:58:08 +0000 2018
# location: Mty N.L
# {'created_at': 'Fri Nov 30 07:58:08 +0000 2018', 'id': 1068413858367369216, 'id_str': '1068413858367369216', 'text': 'RT @MilePicsApp: #MilePics #Free #Android #iPhone #iPad #Porn #Pics #App. More at: https://t.co/gonZ4ONaX5 https://t.co/N6HV6ODn3S', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1004035033617850368, 'id_str': '1004035033617850368', 'name': 'Jose01manuel', 'screen_name': 'Jose01manuel1', 'location': 'Mty N.L', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 374, 'friends_count': 2545, 'listed_count': 0, 'favourites_count': 20130, 'statuses_count': 8067, 'created_at': 'Tue Jun 05 16:19:40 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1005666239346196480/c7Z1L3QB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1005666239346196480/c7Z1L3QB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1004035033617850368/1528604497', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Nov 29 21:38:01 +0000 2018', 'id': 1068257800575438849, 'id_str': '1068257800575438849', 'text': '#MilePics #Free #Android #iPhone #iPad #Porn #Pics #App. More at: https://t.co/gonZ4ONaX5 https://t.co/N6HV6ODn3S', 'display_text_range': [0, 89], 'source': '<a href="https://milepics.com" rel="nofollow">MilePicsApp Feed</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 978981831080062976, 'id_str': '978981831080062976', 'name': 'The Porn App 8K', 'screen_name': 'MilePicsApp', 'location': 'porn land', 'url': 'https://milepics.com', 'description': 'Backup account of http://milepics.com The best porn images app for Android, iPhone and iPad. Main account @MilePics', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 10031, 'friends_count': 136, 'listed_count': 62, 'favourites_count': 39758, 'statuses_count': 106066, 'created_at': 'Wed Mar 28 13:07:11 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'FF691F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1017347557289332736/Esuxwiml_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1017347557289332736/Esuxwiml_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/978981831080062976/1522242894', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordin ...
#
#
#
# Tweet collected at Fri Nov 30 07:58:52 +0000 2018
# location: India
# {'created_at': 'Fri Nov 30 07:58:52 +0000 2018', 'id': 1068414042467786753, 'id_str': '1068414042467786753', 'text': 'Mobile accessories for wholesale here- https://t.co/onBRw9Fjo9\n#iPhone #FridayFeeling #FridayMotivation https://t.co/nwc2wgjPDp', 'display_text_range': [0, 103], 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 946316960358285312, 'id_str': '946316960358285312', 'name': 'Grapheneglass', 'screen_name': 'grapheneglass', 'location': 'India', 'url': 'https://graphenearmorglass.com', 'description': 'The site of mobile accessories in India\nall tempered glass and cover visit our website http://goo.gl/xdKib2 .', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 46, 'friends_count': 86, 'listed_count': 1, 'favourites_count': 1520, 'statuses_count': 2139, 'created_at': 'Thu Dec 28 09:48:39 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '91D2FA', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/989799411755700224/fhyi6yOK_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989799411755700224/fhyi6yOK_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/946316960358285312/1514542716', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'iPhone', 'indices': [63, 70]}, {'text': 'FridayFeeling', 'indices': [71, 85]}, {'text': 'FridayMotivation', 'indices': [86, 103]}], 'urls': [{'url': 'https://t.co/onBRw9Fjo9', 'expanded_url': 'https://graphenearmorglass.com', 'display_url': 'graphenearmorglass.com', 'indices': [39, 62]}], 'user_mentions': [], 'symbols': [], 'media': [{'id': 1068413937908047873, 'id_str': '1068413937908047873', 'indices': [104, 127], 'media_url': 'http://pbs.twimg.com/media/DtPE0NoV4AEwluf.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DtPE0NoV4AEwluf.jpg', 'url': 'https://t.co/nwc2wgjPDp', 'display_url': 'pic.twitter.com/nwc2wgjPDp', 'expanded_url': 'https://twitter.com/grapheneglass/status/1068414042467786753/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 400, 'h': 400, 'resize': 'fit'}, 'small': {'w': 400, 'h': 400, 'resize': 'fit'}, 'medium': {'w': 400, 'h': 400, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1068413937908047873, 'id_str': '1068413937908047873', 'indices': [104, 127], 'media_url': 'http://pbs.twimg.com/media/DtPE0NoV4AEwluf.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DtPE0NoV4AEwluf.jpg', 'url': 'https://t.co/nwc2wgjPDp', 'display_url': 'pic.twitter.com/nwc2wgjPDp', 'expanded_url': 'https://twitter.com/grapheneglass/status/1068414042467786753/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 400, 'h': 400, 'resize': 'fit'}, 'small': {'w': 400, 'h': 400, 'resize': 'fit'}, 'medium': {'w': 400, 'h': 400, 'resize': 'fit'}}}]}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1543564 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-761b7253cac7> in <module>()
#      56 streamer = tweepy.Stream(auth=auth, listener=listener)
#      57 print("Tracking: " + str(WORDS))
# ---> 58 streamer.filter(languages=["en"], track=WORDS)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
client = MongoClient(MONGO_HOST)
            
            # Use twitterdb database. If it doesn't exist, it will be created.
db = client.twitterdb

cursor = db.twitter_search.find().limit(5000).sort([("created_at",-1)])

# cursor = db.collection.find().limit(200).sort([("created_at",-1)])

# %%
import pandas as pd
new_df = pd.DataFrame(columns = ['location'])
HASHTAGS = ['airpod','ipad','macbook','iphone','iwatch']

states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
for post in cursor:
    if str(post['user']['location']).split(', ')[-1] in states:
        print('loc', str(post['user']['location']).split(', ')[-1])
        for i, hashtag in enumerate(post['entities']['hashtags']):
#             print(post['entities']['hashtags'][i]['text'])
            if post['entities']['hashtags'][i]['text'] in HASHTAGS:
                new_df = new_df.append({'location' : str(post['user']['location']).split(', ')[-1], 
                                        'time' : post['created_at'],
                                        'tag' : post['entities']['hashtags'][i]['text']},
                                         ignore_index=True)
                print('tag:', post['entities']['hashtags'][i]['text'])
# Out:
# loc NC
# loc MA
# loc GA
# loc CA
# loc TX
# loc MI
# loc LA
# loc GA
# loc MI
# loc MA
# loc CT
# loc NY
# loc CO
# loc TX
# loc UT
# loc CA
# loc NC
# loc CA
# loc IA
# loc CA
# loc CA
# loc TX
# loc TX
# loc DC

# %%
new_df.describe()
# Out:
#         location
# count          0
# unique         0
