# %%
from emotion_predictor import EmotionPredictor

# %%
model = EmotionPredictor(classification='ekman', setting='mc', use_unison_model=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py:1271: UserWarning: Update your `InputLayer` call to the Keras 2 API: `InputLayer(batch_input_shape=[None, 143..., name="input_1", sparse=False, dtype="float32")`
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py:1271: UserWarning: The `dropout` argument is no longer support in `Embedding`. You can apply a `keras.layers.SpatialDropout1D` layer right after the `Embedding` layer to get the same behavior.
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py:1271: UserWarning: Update your `Embedding` call to the Keras 2 API: `Embedding(output_dim=25, input_dtype="int32", name="embedding_1", mask_zero=False, trainable=True, batch_input_shape=[None, Non..., input_dim=412, activity_regularizer=None, input_length=None, embeddings_initializer="uniform", embeddings_regularizer=None, embeddings_constraint=None)`
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py:1271: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(name="dropout_1", trainable=True, rate=0.2)`
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py:2248: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py:2248: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(name="lstm_1", stateful=False, batch_input_shape=[None, Non..., input_dtype="float32", trainable=True, activation="tanh", unroll=False, return_sequences=False, go_backwards=False, unit_forget_bias=True, input_shape=(None, 25), units=400, kernel_initializer="glorot_uniform", recurrent_initializer="orthogonal", recurrent_activation="hard_sigmoid", kernel_regularizer=None, bias_regularizer=None, recurrent_regularizer=None, dropout=0.0, recurrent_dropout=0.0, implementation=0)`
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py:2107: UserWarning: `implementation=0` has been deprecated, and now defaults to `implementation=1`.Please update your layer call.
#   warnings.warn('`implementation=0` has been deprecated, '
# /anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py:2248: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(name="lstm_2", stateful=False, batch_input_shape=[None, Non..., input_dtype="float32", trainable=True, activation="tanh", unroll=False, return_sequences=False, go_backwards=True, unit_forget_bias=True, input_shape=(None, 25), units=400, kernel_initializer="glorot_uniform", recurrent_initializer="orthogonal", recurrent_activation="hard_sigmoid", kernel_regularizer=None, bias_regularizer=None, recurrent_regularizer=None, dropout=0.0, recurrent_dropout=0.0, implementation=0)`
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py:1271: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py:1271: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(name="dropout_2", trainable=True, rate=0.5)`
#   return cls(**config)
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py:1271: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(name="dense_1", trainable=True, activation="softmax", activity_regularizer=None, input_dim=None, units=6, kernel_initializer="glorot_uniform", kernel_regularizer=None, bias_regularizer=None, kernel_constraint=None, bias_constraint=None, use_bias=True)`
#   return cls(**config)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-cf2a7f3e59a2> in <module>()
# ----> 1 model = EmotionPredictor(classification='ekman', setting='mc', use_unison_model=True)
#
# <ipython-input-6-2692c6f1c740> in __init__(self, classification, setting, use_unison_model)
#      28         self.setting = setting
#      29         self.use_unison_model = use_unison_model
# ---> 30         self.model = self._get_model()
#      31         self.embeddings_model = self._get_embeddings_model()
#      32         self.char_to_ind = self._get_char_mapping()
#
# <ipython-input-6-2692c6f1c740> in _get_model(self)
#      40             self.setting,
#      41         )
# ---> 42         return load_model(self._loaded_model_filename)
#      43
#      44     def _get_embeddings_model(self):
#
# /anaconda3/lib/python3.6/site-packages/keras/models.py in load_model(filepath, custom_objects, compile)
#     241         self.trainable = True
#     242
# --> 243         # model attributes
#     244         self.inbound_nodes = []
#     245         self.outbound_nodes = []
#
# /anaconda3/lib/python3.6/site-packages/keras/models.py in model_from_config(config, custom_objects)
#     315             # update self.inbound_nodes
#     316             self.inbound_nodes[0].output_tensors = self.outputs
# --> 317             self.inbound_nodes[0].output_shapes = [self.outputs[0]._keras_shape]
#     318
#     319         self.layers.append(layer)
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#
# /anaconda3/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     142                 info += ' - %ds' % (now - self.start)
#     143             for k in self.unique_values:
# --> 144                 info += ' - %s:' % k
#     145                 if type(self.sum_values[k]) is list:
#     146                     avg = self.sum_values[k][0] / max(1, self.sum_values[k][1])
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in from_config(cls, config, custom_objects)
#    2522                 raise Exception('You are trying to load a weight file '
#    2523                                 'containing ' + str(nb_layers) +
# -> 2524                                 ' layers into a model with ' +
#    2525                                 str(len(flattened_layers)) + ' layers.')
#    2526
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in process_node(layer, node_data)
#    2479         '''Load all layer weights from a HDF5 save file.
#    2480
# -> 2481         If `by_name` is False (default) weights are loaded
#    2482         based on the network's topology, meaning the architecture
#    2483         should be the same as when the weights were saved.
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     590
#     591         # Arguments
# --> 592             input: tensor or list of tensors.
#     593             input_mask: tensor or list of tensors.
#     594
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/embeddings.py in build(self, input_shape)
#     103         if self.W_regularizer:
#     104             self.W_regularizer.set_param(self.W)
# --> 105             self.regularizers.append(self.W_regularizer)
#     106
#     107         if self.activity_regularizer:
#
# /anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint)
#     414                     raise Exception('Input ' + str(input_index) +
#     415                                     ' is incompatible with layer ' +
# --> 416                                     self.name + ': expected dtype=' +
#     417                                     str(spec.dtype) + ', found dtype=' +
#     418                                     str(K.dtype(x)))
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in variable(value, dtype, name, constraint)
#     393     if axes is not None:
#     394         adj_x = None if axes[0] == ndim(x) - 1 else True
# --> 395         adj_y = True if axes[1] == ndim(y) - 1 else None
#     396     else:
#     397         adj_x = None
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint)
#     233           dtype=dtype,
#     234           expected_shape=expected_shape,
# --> 235           constraint=constraint)
#     236
#     237   def __repr__(self):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in _init_from_args(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, expected_shape, constraint)
#     347         else:
#     348           self._initial_value = ops.convert_to_tensor(
# --> 349               initial_value, name="initial_value", dtype=dtype)
#     350           # pylint: disable=protected-access
#     351           if self._initial_value.op._get_control_flow_context() is not None:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, preferred_dtype)
#     948       name=name,
#     949       preferred_dtype=preferred_dtype,
# --> 950       as_ref=False)
#     951
#     952
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1038
#    1039     if ret is None:
# -> 1040       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1041
#    1042     if ret is NotImplemented:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _TensorTensorConversionFunction(t, dtype, name, as_ref)
#     881     raise ValueError(
#     882         "Tensor conversion requested dtype %s for Tensor with dtype %s: %r" %
# --> 883         (dtype.name, t.dtype.name, str(t)))
#     884   return t
#     885
#
# ValueError: Tensor conversion requested dtype int32 for Tensor with dtype float32: 'Tensor("embedding_1_3/random_uniform:0", shape=(412, 25), dtype=float32)'
