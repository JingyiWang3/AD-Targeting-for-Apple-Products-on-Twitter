# %%
# Import data from mongodb
import pymongo
from pymongo import MongoClient
client = pymongo.MongoClient("mongodb+srv://yh2866:Aa123456@cluster0-5mcg4.mongodb.net/tttest?retryWrites=true")
cursor = client['twitterdb']['AirPods']

# Save to a dataframe
import pandas as pd
twitterdf = pd.DataFrame(list(cursor.find()))
print(twitterdf.shape)
# Out:
# (3056, 42)

# %% [markdown]
# ### User Profile Word Cloud

# %%
from CreateWordCloud import get_wordcloud
get_wordcloud(twitterdf)

# %% [markdown]
# ### Tweet Sentiment Word Cloud

# %%
from SentimentAnalysis import get_sentiment
get_sentiment(twitterdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8b08af275049> in <module>()
#       1 from SentimentAnalysis import get_sentiment
# ----> 2 get_sentiment(twitterdf)
#
# ~/Google Drive/6893 Big Data Analytics/E6893-Big-Data-Project/Models/SentimentAnalysis.py in get_sentiment(df)
#      43 def get_sentiment(df):
#      44
# ---> 45     cleaned = get_cleaned_df(df)
#      46     cleaned['polarity'] = cleaned.apply(lambda x: TextBlob(x['text']).sentiment.polarity, axis=1)
#      47     cleaned['subjectivity'] = cleaned.apply(lambda x: TextBlob(x['text']).sentiment.subjectivity, axis=1)
#
# ~/Google Drive/6893 Big Data Analytics/E6893-Big-Data-Project/Models/SentimentAnalysis.py in get_cleaned_df(df)
#      17 def get_cleaned_df(df):
#      18     # to lower case + remove stop words
# ---> 19     clean = df.text.apply(lambda x: filter_tweet(x))
#      20
#      21     # remove duplicated tweets
#
# NameError: name 'twitterdf' is not defined
