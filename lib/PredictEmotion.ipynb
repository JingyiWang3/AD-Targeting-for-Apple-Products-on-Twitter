# %%
from emotion_predictor import EmotionPredictor
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
#tf.python.control_flow_ops = tf

model = EmotionPredictor(classification='ekman', setting='mc')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-de5877f5227d> in <module>()
#       2 #tf.python.control_flow_ops = tf
#       3
# ----> 4 model = EmotionPredictor(classification='ekman', setting='mc')
#
# ~/Desktop/BDA-FINAL PROJECT/E6893-Big-Data-Project/lib/emotion_predictor.py in __init__(self, classification, setting, use_unison_model)
#      28         self.setting = setting
#      29         self.use_unison_model = use_unison_model
# ---> 30         self.model = self._get_model()
#      31         self.embeddings_model = self._get_embeddings_model()
#      32         self.char_to_ind = self._get_char_mapping()
#
# ~/Desktop/BDA-FINAL PROJECT/E6893-Big-Data-Project/lib/emotion_predictor.py in _get_model(self)
#      40             self.setting,
#      41         )
# ---> 42         return load_model(self._loaded_model_filename)
#      43
#      44     def _get_embeddings_model(self):
#
# /anaconda3/lib/python3.6/site-packages/keras/models.py in load_model(filepath, custom_objects)
#     126         raise ValueError('No model found in config file.')
#     127     model_config = json.loads(model_config.decode('utf-8'))
# --> 128     model = model_from_config(model_config, custom_objects=custom_objects)
#     129
#     130     # set weights
#
# /anaconda3/lib/python3.6/site-packages/keras/models.py in model_from_config(config, custom_objects)
#     175         raise Exception('`model_fom_config` expects a dictionary, not a list. '
#     176                         'Maybe you meant to use `Sequential.from_config(config)`?')
# --> 177     return layer_from_config(config, custom_objects=custom_objects)
#     178
#     179
#
# /anaconda3/lib/python3.6/site-packages/keras/utils/layer_utils.py in layer_from_config(config, custom_objects)
#      34         layer_class = get_from_module(class_name, globals(), 'layer',
#      35                                       instantiate=False)
# ---> 36     return layer_class.from_config(config['config'])
#      37
#      38
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in from_config(cls, config, custom_objects)
#    2373
#    2374         for layer_data in config['layers']:
# -> 2375             process_layer(layer_data)
#    2376
#    2377         name = config.get('name')
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in process_layer(layer_data)
#    2368                 if input_tensors:
#    2369                     if len(input_tensors) == 1:
# -> 2370                         layer(input_tensors[0])
#    2371                     else:
#    2372                         layer(input_tensors)
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, x, mask)
#     485                                     '`layer.build(batch_input_shape)`')
#     486             if len(input_shapes) == 1:
# --> 487                 self.build(input_shapes[0])
#     488             else:
#     489                 self.build(input_shapes)
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py in build(self, input_shape)
#     708                                       self.W_o, self.U_o, self.b_o]
#     709
# --> 710             self.W = K.concatenate([self.W_i, self.W_f, self.W_c, self.W_o])
#     711             self.U = K.concatenate([self.U_i, self.U_f, self.U_c, self.U_o])
#     712             self.b = K.concatenate([self.b_i, self.b_f, self.b_c, self.b_o])
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in concatenate(tensors, axis)
#     714         return tf.sparse_concat(axis, tensors)
#     715     else:
# --> 716         return tf.concat(axis, [to_dense(x) for x in tensors])
#     717
#     718
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in concat(values, axis, name)
#    1045       ops.convert_to_tensor(axis,
#    1046                             name="concat_dim",
# -> 1047                             dtype=dtypes.int32).get_shape(
#    1048                             ).assert_is_compatible_with(tensor_shape.scalar())
#    1049       return identity(values[0], name=scope)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, preferred_dtype)
#     649       name=name,
#     650       preferred_dtype=preferred_dtype,
# --> 651       as_ref=False)
#     652
#     653
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype)
#     714
#     715         if ret is None:
# --> 716           ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     717
#     718         if ret is NotImplemented:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     174                                          as_ref=False):
#     175   _ = as_ref
# --> 176   return constant(v, dtype=dtype, name=name)
#     177
#     178
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     163   tensor_value = attr_value_pb2.AttrValue()
#     164   tensor_value.tensor.CopyFrom(
# --> 165       tensor_util.make_tensor_proto(value, dtype=dtype, shape=shape, verify_shape=verify_shape))
#     166   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     167   const_tensor = g.create_op(
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     365       nparray = np.empty(shape, dtype=np_dt)
#     366     else:
# --> 367       _AssertCompatible(values, dtype)
#     368       nparray = np.array(values, dtype=np_dt)
#     369       # check to them.
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/tensor_util.py in _AssertCompatible(values, dtype)
#     300     else:
#     301       raise TypeError("Expected %s, got %s of type '%s' instead." %
# --> 302                       (dtype.name, repr(mismatch), type(mismatch).__name__))
#     303
#     304
#
# TypeError: Expected int32, got <tensorflow.python.ops.variables.Variable object at 0x3216f0278> of type 'Variable' instead.

# %%
# Out:
# TensorFlow version: 1.12.0
